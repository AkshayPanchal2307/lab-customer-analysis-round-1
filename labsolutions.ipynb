# %%
import pandas as pd 
import numpy as np

# %%
file1 = pd.read_csv("file1.csv")
file2 = pd.read_csv("file2.csv")
file3 = pd.read_csv("file3.csv")

# %%
print(file1.shape)
print(file2.shape)
print(file3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file1.columns=file1.columns.astype("str")

# %%
file1.columns=file1.columns.map(str.upper)

# %%
file1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
data = pd.concat([file1, file2, file3], axis=0) 
print(data.shape)
display(data)
# Out:
# (12074, 22)
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      CUSTOMER LIFETIME VALUE   INCOME  MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
cols=file1.columns

# %%
num_cols=file1._get_numeric_data().columns

# %%
num_cols
# Out:
# Index(['INCOME', 'MONTHLY PREMIUM AUTO', 'TOTAL CLAIM AMOUNT'], dtype='object')

# %%
list(set(cols)-set(num_cols))
# Out:
# ['NUMBER OF OPEN COMPLAINTS',
#  'POLICY TYPE',
#  'GENDER',
#  'EDUCATION',
#  'VEHICLE CLASS',
#  'CUSTOMER',
#  'ST',
#  'CUSTOMER LIFETIME VALUE']

# %%
file1=file1.drop(columns=['EDUCATION','NUMBER OF OPEN COMPLAINTS'])

# %%
file1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'CUSTOMER LIFETIME VALUE', 'INCOME',
#        'MONTHLY PREMIUM AUTO', 'POLICY TYPE', 'VEHICLE CLASS',
#        'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
file1=file1.drop_duplicates()
file1.shape
# Out:
# (1072, 9)

# %%
file1['CUSTOMER LIFETIME VALUE'] = file1['CUSTOMER LIFETIME VALUE'].str.rstrip('%').astype('float') / 100.0

# %%
file1.head()
# Out:
#   CUSTOMER          ST GENDER  CUSTOMER LIFETIME VALUE   INCOME  \
# 0  RB50392  Washington    NaN                      NaN      0.0
# 1  QZ44356     Arizona      F                6979.5359      0.0
# 2  AI49188      Nevada      F               12887.4317  48767.0
# 3  WW63253  California      M                7645.8618      0.0
# 4  GA49547  Washington      M                5363.0765  36357.0
#
#    MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %%
file1[file1['INCOME']<=0]
# Out:
#      CUSTOMER          ST GENDER  CUSTOMER LIFETIME VALUE  INCOME  \
# 0     RB50392  Washington    NaN                      NaN     0.0
# 1     QZ44356     Arizona      F                6979.5359     0.0
# 3     WW63253  California      M                7645.8618     0.0
# 7     CF85061     Arizona      M                7216.1003     0.0
# 10    SX51350  California      M                4738.9920     0.0
# ...       ...         ...    ...                      ...     ...
# 1046  RG30482      Oregon      F               13668.3553     0.0
# 1048  QQ39596     Arizona      F                2517.5336     0.0
# 1055  KJ86296      Oregon      M                4556.5930     0.0
# 1058  UX92071      Oregon      M                6743.1193     0.0
# 1061  RY92647        Cali      F               10506.7717     0.0
#
#       MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS  TOTAL CLAIM AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
